# %%
import sympy as sp
from sympy import *
from sympy.abc import *
from sympy.parsing.sympy_parser import parse_expr
import itertools

# %%
NNF_FILE_NAME = 'nnf/1.nnf'
CNF_FILE_NAME = 'cnf/1.cnf'

# %%
class MisMatchedBrackets(Exception):
    pass
class EmptyBrackets(Exception):
    pass
class NANException(Exception):
    pass
class OperatorAfterOperatorException(Exception):
    pass
class OperatorAtIndex0(Exception):
    pass
class OperatorAtEnd(Exception):
    pass
class SubformulaError(Exception):
    pass
class DepthError(Exception):
    pass
class Tseitin_Aux(Exception):
    pass
class CNFError(Exception):
    pass

# %%
def detect_operator_errors(NNF: str):
    if '.+' in NNF:
        raise OperatorAfterOperatorException('.+ found in string')
    elif '+.' in NNF:
        raise OperatorAfterOperatorException('+. found in string')
    elif '--' in NNF:
        raise OperatorAfterOperatorException('Double negation found in string')
    if NNF[0] in ('.', '+'):
        raise OperatorAtIndex0(f'Operator {NNF[0]} found at index 0')
    elif NNF[-1] in ('.', '+'):
        raise OperatorAtEnd(f'Operator {NNF[-1]} found at end of NNF')

# %%
def detect_incorrect_brackets(NNF: str):
    emptyBracket = NNF.find('()')
    if emptyBracket != -1:
        raise EmptyBrackets(f'Empty Brackets at index {emptyBracket+1}')
    st = []
    le = len(NNF)
    for i in range(le):
        char = NNF[i]
        if char == '(':
            st.append(i)
        elif char == ')':
            if st == []:
                raise MisMatchedBrackets(f'Extra closing bracket at index {i+1} in file')
            st.pop()
        
    if st != []:
        raise MisMatchedBrackets(f'Unpaired opening bracket at index {st[0]+1} in file')

# %%
def read_NNF_from_file(filename: str=NNF_FILE_NAME):
    f = open(filename, "r")
    line = f.readline()
    for i in range(len(line)-1,-1,-1):
        char = line[i]
        if char == '0':
            line = line[:i]
            break
    line = line.replace(' ', '')
    return line.strip()

# %%
NNF_STRING = read_NNF_from_file()

# %%
NNF_STRING
# Out:
# '1.(2+(3.5)+-1.3)+4.6+12+15'

# %%
def max_no(clause: str):
    final = []
    clause = clause.replace('(', '')
    clause = clause.replace(')', '')
    dot_split = clause.split('.')
    for ds in dot_split:
        final.extend(ds.split('+'))
    for i in range(len(final)):
        try:
            final[i] = abs(int(final[i]))
        except:
            raise NANException(f'Found an invalid character "{final[i]}"')
    return max(final)

# %%
def define_variables(max_no: int):
    return symbols(f'x:{max_no}')

# %%
max_num:int  = max_no(NNF_STRING)
syms: sp.Symbol = define_variables(max_num+1)
for i in range(max_num+1):
    exec(f'x{i} = syms[{i}]')

# %%
def replace_nums_with_symbols(clause: str)->str:
    max_num = max_no(clause)
    clause = clause.replace('-', '~')
    split_by_and = clause.split('.')
    syms = define_variables(max_num+1)
    for i in range(max_num+1):
        exec(f'x{i} = syms[{i}]')
    fin_clause = ''
    for sub_clause in split_by_and:
        fin_sub_clause = ''
        for sub_sub_clause in sub_clause.split('+'):
            for i in range(max_num, 0, -1):
                if sub_sub_clause.replace(str(i), str(syms[i])) != sub_sub_clause:
                    sub_sub_clause = sub_sub_clause.replace(str(i), str(syms[i]))
                    break
            fin_sub_clause = fin_sub_clause + '|' + sub_sub_clause
        
        fin_clause = fin_clause + '&' + fin_sub_clause[1:]
    return fin_clause[1:]

# %%
type(parse_expr('x1 & x2 | x3 | x5'))
# Out:
# Or

# %%
def get_sp_clause(clause: str):
    converted_clause_string = replace_nums_with_symbols(clause)
    try:
        return parse_expr(converted_clause_string)
    except Exception as e:
        print(f'Error in clause {clause} {e}')

# %%
def subformulas(expr):
# subformula of expr without atoms
# considering operator as binary
    
    if expr.func == sp.Symbol:
        return []
    elif len(expr.args)==1:
        return [expr] + subformulas(expr.args[0])
    elif len(expr.args)==2:
        return [expr] + subformulas(expr.args[0]) + subformulas(expr.args[1]) 
    elif len(expr.args)>2:
        return [expr] + subformulas(expr.args[0]) + subformulas(eval(str(expr.func)+str(expr.args[1:])))  
    else:
        raise SubformulaError(f'For input expr {expr}')

# %%
def depth(expr):
# still considering operator as binary
    if expr.func == Not:
        return 1 + depth(expr.args[0])
    elif (len(expr.args)==2):
        return 1 + max([depth(x) for x in expr.args])
    elif ( len(expr.args)>2):
        #return 1 + max(depth(expr.args[0]), depth(eval(str(expr.func)+str(expr.args[1:]))))
        return len(expr.args)-1 + max([depth(x) for x in expr.args])
    elif expr.func == Symbol:
        return 0
    else: 
        raise DepthError(f'For input expr {expr}')

# %%
def symbol_init(x, count=0):
    def new_symbol ():
        nonlocal count
        count += 1
        return var(str(x) + str(count)) #var add the new symbol in the name space
    return new_symbol

# %%
def binSubs(x, y, z):
    #replace y by z in x
    #print("subs", x, y, z)
    if (len(y.args) >0) and (len(x.args)>2) and (y!=x) and (y.func==x.func):
     
        if all([y in x.args for y in y.args]): 
            l = list(x.args)
            for i in y.args:
                l.remove(i)
            if (z.func== Symbol):
                t=tuple(l + [z])
            else:
                t=tuple(l+list(z.args))
            return eval(str(x.func) + str(t))
    
    return x.subs(y,z)

# %%
def tseitin1(string):
    # for binary operation
    try:
        expr = get_sp_clause(string)
        s=symbol_init("p")
        if expr.func == Symbol:
            return true
        else:
            return tseitin_aux(sorted(set(subformulas(expr)), key=depth), s) 
    except Exception as e:
        raise e
        return None

def tseitin_aux(L, s):
    #nonlocal newvar
    newvar = s()
    if (L==[]):
        return true
    if depth(L[0]) > 0:
        if len(L[1:])>0 :
            #newList = [x.subs(L[0], newvar) for x in L[1:]]  
            
            newList = [binSubs(x, L[0], newvar) for x in L[1:]]  
            
            return Equivalent(newvar, L[0]) & tseitin_aux(newList, s)
        else:      
            return Equivalent(newvar, L[0]) & newvar
    else:
        raise Tseitin_Aux(f'Error for arguments L:{L} s:{s}')

# %%
def demorgan(a, neg=False, depth=0):
#     print(a)
#     print(depth*"\t","demorgan", a)
    s = f''
#     print(depth*"\t", a)
    if a.func == sp.Or:
        ls = []
        for i in range(len(a.args)):
            if a.args[i].func == sp.And:
    #             print(depth*"\t",'1')
                ls.append(a.args[i].args)
            elif a.args[i].func == sp.Symbol:
                ls.append([a.args[i]])
            elif len(a.args[i].args) == 1:
                ls.append([a.args[i]])
            else:
                print('a', a.args[i])
#                 ls.append()
        ls2 = []
        for element in itertools.product(*ls):
            ls2.append(parse_expr('Or' + str(tuple(element))))
        ls2_str = 'And(' + str(ls2)[1:-1] + ')'
#         print('ls2', ls2_str)
        return parse_expr(ls2_str)
    else:
        return a

# %%
def cnf(a, neg=False, depth=0):
#     print(depth*'\t', a, a.func, len(a.args), neg)
    if a.func == sp.Symbol:
        if neg:
            return ~a
        else:
            return a
    elif len(a.args)==1:
#         print(a.args)
        return cnf(eval(str(a.args[0])), neg=not neg, depth=depth+1)
    elif len(a.args)==2 and a.func == sp.Equivalent:
        if not neg:
            return demorgan(demorgan(cnf(a.args[0], depth=depth+1), depth=depth+1) | demorgan(cnf(a.args[1], neg=True, depth=depth+1), depth=depth+1), depth=depth+1) & demorgan(demorgan(cnf(a.args[0], neg=True, depth=depth+1), depth=depth+1) | demorgan(cnf(a.args[1], depth=depth+1), depth=depth+1), depth=depth+1)
        else:
            assert False
            # return (cnf(a.args[0], neg=True, depth=depth+1) | cnf(a.args[1], neg=True, depth=depth+1) & (cnf(a.args[1], neg=False, depth=depth+1) | cnf(a.args[0], neg=False, depth=depth+1)))
    elif len(a.args)>=2:
        if a.func == sp.And:
            if not neg:
                return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
            else:
                return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
        elif a.func == sp.Or:
            if not neg:
                return demorgan(cnf(a.args[0], depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
            else:
                return demorgan(cnf(a.args[0], depth=depth+1, neg=neg) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=neg, depth=depth+1), depth=depth+1), depth=depth+1)
    else:
        raise CNFError(f'For input {a}')

# %%
def set_wrapper(cnf_ans):
    set_of_vars = {}
    counter = 1
    def recursive_add_to_set(a):
        nonlocal counter
        if a.func == sp.Symbol:
            if a not in set_of_vars:
                set_of_vars[a] = counter
                counter += 1
        elif len(a.args)==1:
            b = a.args[0]
            if b not in set_of_vars:
                set_of_vars[b] = counter
                counter += 1
        else:
            for arg in a.args:
                recursive_add_to_set(arg)
    recursive_add_to_set(cnf_ans)
    return set_of_vars

# %%
def write_cnf(filename, cnf_ans, set_of_vars):
    assert cnf_ans.func == sp.And
    l = [f'p cnf {len(set_of_vars)} {len(cnf_ans.args)}']
    for arg in cnf_ans.args:
        s = ''
        if arg.func == sp.Symbol:
            s += str(set_of_vars[arg]) + ' '
        else:
            assert arg.func == sp.Or
            for sub_arg in arg.args:
                if len(sub_arg.args) == 1:
                    s += str(-1*(set_of_vars[sub_arg.args[0]])) + ' '
                elif len(sub_arg.args) == 0:
                    s += str(set_of_vars[sub_arg]) + ' '
        s += '0 '
        l.append(s)
    with open(filename,'w') as f:
        f.write('\n'.join(l))

# %%
def make_cnf(s):
    global CNF_FILE_NAME
    clause = tseitin1(s)
    cnf_ans = cnf(clause)
    set_of_vars = set_wrapper(cnf_ans)
    write_cnf(CNF_FILE_NAME, cnf_ans, set_of_vars)
    return cnf_ans

# %%
make_cnf(NNF_STRING)
# Out:
# p10 & (p2 | x1) & (p10 | ~p9) & (p10 | ~x12) & (p2 | ~p4) & (p5 | ~p3) & (p5 | ~p4) & (p6 | ~p5) & (p6 | ~x2) & (p8 | ~p1) & (p8 | ~p7) & (p9 | ~p8) & (p9 | ~x15) & (x1 | ~p7) & (x3 | ~p3) & (x3 | ~p4) & (x4 | ~p1) & (x5 | ~p3) & (x6 | ~p1) & (~p2 | ~x1) & (p1 | p7 | ~p8) & (p3 | p4 | ~p5) & (p5 | x2 | ~p6) & (p8 | x15 | ~p9) & (p9 | x12 | ~p10) & (p1 | ~x4 | ~x6) & (p3 | ~x3 | ~x5) & (p4 | ~p2 | ~x3) & (p7 | ~p3 | ~x1) & (p7 | ~p4 | ~x1) & (p7 | ~x1 | ~x2) & (p3 | p4 | x2 | ~p7)

# %%
NNF_STRING
# Out:
# '1.(2+(3.5)+-1.3)+4.6+12+15'

# %%
sp.to_cnf(tseitin1(NNF_STRING)) == make_cnf(NNF_STRING)
# Out:
# True

# %%
for i in range(1, 40):
    NNF_FILE_NAME = f'nnf/test_case{i}.nnf'
    CNF_FILE_NAME = f'cnf/test_case{i}.cnf'
    NNF_STRING = read_NNF_from_file(NNF_FILE_NAME)
    detect_incorrect_brackets(NNF_STRING)
    detect_operator_errors(NNF_STRING)
    max_num:int  = max_no(NNF_STRING)
    syms: sp.Symbol = define_variables(max_num+1)
    for j in range(max_num+1):
        exec(f'x{j} = syms[{j}]')
    print(NNF_FILE_NAME, i, sp.to_cnf(tseitin1(NNF_STRING)) == make_cnf(NNF_STRING))
# Out:
# nnf/test_case1.nnf 1 True
# nnf/test_case2.nnf 2 True
# nnf/test_case3.nnf 3 True
# nnf/test_case4.nnf 4 True
# nnf/test_case5.nnf 5 True
# nnf/test_case6.nnf 6 True
# nnf/test_case7.nnf 7 True
# nnf/test_case8.nnf 8 True
# nnf/test_case9.nnf 9 True
# nnf/test_case10.nnf 10 True
# nnf/test_case11.nnf 11 True
# nnf/test_case12.nnf 12 True
# nnf/test_case13.nnf 13 True
# nnf/test_case14.nnf 14 True
# nnf/test_case15.nnf 15 True
# nnf/test_case16.nnf 16 True
# nnf/test_case17.nnf 17 True
# nnf/test_case18.nnf 18 True
# nnf/test_case19.nnf 19 True
# nnf/test_case20.nnf 20 True
# nnf/test_case21.nnf 21 True
# nnf/test_case22.nnf 22 True
# nnf/test_case23.nnf 23 True
# nnf/test_case24.nnf 24 True
# nnf/test_case25.nnf 25 True
# nnf/test_case26.nnf 26 True
# nnf/test_case27.nnf 27 True
# nnf/test_case28.nnf 28 True
# nnf/test_case29.nnf 29 True
# nnf/test_case30.nnf 30 True
# nnf/test_case31.nnf 31 True
# nnf/test_case32.nnf 32 True
# nnf/test_case33.nnf 33 True
# nnf/test_case34.nnf 34 True
# nnf/test_case35.nnf 35 True
# nnf/test_case36.nnf 36 True
# nnf/test_case37.nnf 37 True
# nnf/test_case38.nnf 38 True
# nnf/test_case39.nnf 39 True

# %%
try:
    NNF_FILE_NAME = f'nnf/3.nnf'
    CNF_FILE_NAME = f'cnf/3.cnf'
    NNF_STRING = read_NNF_from_file(NNF_FILE_NAME)
    detect_incorrect_brackets(NNF_STRING)
    detect_operator_errors(NNF_STRING)
    print(i, sp.to_cnf(tseitin1(NNF_STRING)) == make_cnf(NNF_STRING))
except NANException as e:
    print(f'recieved a NANException as Expected: {e}')
# Out:
# recieved a NANException as Expected: Found an invalid character "a"

# %%
try:
    read_NNF_from_file('nnf/-1.nnf')
except FileNotFoundError as e:
    print(f'recieved a FileNotFoundError as Expected: {e}')
# Out:
# recieved a FileNotFoundError as Expected: [Errno 2] No such file or directory: 'nnf/-1.nnf'

# %%
try:
    NNF_STRING = read_NNF_from_file('nnf/0.nnf')
    detect_incorrect_brackets(NNF_STRING)
    detect_operator_errors(NNF_STRING)
except EmptyBrackets as e:
    print(f'recieved a EmptyBrackets as Expected: {e}')
# Out:
# recieved a EmptyBrackets as Expected: Empty Brackets at index 14

# %%
try:
    NNF_STRING = read_NNF_from_file('nnf/2.nnf')
    detect_incorrect_brackets(NNF_STRING)
    detect_operator_errors(NNF_STRING)
except MisMatchedBrackets as e:
    print(f'recieved a MisMatchedBrackets as Expected: {e}')
# Out:
# recieved a MisMatchedBrackets as Expected: Unpaired opening bracket at index 3 in file

# %%
for i in range(10):
    NNF_FILE_NAME = f'nnf/fuzzy_testcase_{i}.nnf'
    CNF_FILE_NAME = f'cnf/fuzzy_testcase_{i}.cnf'
    NNF_STRING = read_NNF_from_file(NNF_FILE_NAME)
    detect_incorrect_brackets(NNF_STRING)
    detect_operator_errors(NNF_STRING)
    max_num:int  = max_no(NNF_STRING)
    syms: sp.Symbol = define_variables(max_num+1)
    for j in range(max_num+1):
        exec(f'x{j} = syms[{j}]')
    print(NNF_FILE_NAME, i, sp.to_cnf(tseitin1(NNF_STRING)) == make_cnf(NNF_STRING))
# Out:
# nnf/fuzzy_testcase_0.nnf 0 True
# nnf/fuzzy_testcase_1.nnf 1 True
# nnf/fuzzy_testcase_2.nnf 2 True
# nnf/fuzzy_testcase_3.nnf 3 True
# nnf/fuzzy_testcase_4.nnf 4 True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-eb97f6dbafbd> in <module>
#       9     for j in range(max_num+1):
#      10         exec(f'x{j} = syms[{j}]')
# ---> 11     print(NNF_FILE_NAME, i, sp.to_cnf(tseitin1(NNF_STRING)) == make_cnf(NNF_STRING))
#
# <ipython-input-24-0719c94bf466> in make_cnf(s)
#       2     global CNF_FILE_NAME
#       3     clause = tseitin1(s)
# ----> 4     cnf_ans = cnf(clause)
#       5     set_of_vars = set_wrapper(cnf_ans)
#       6     write_cnf(CNF_FILE_NAME, cnf_ans, set_of_vars)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
# ...
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# <ipython-input-21-1f329e75eaa1> in cnf(a, neg, depth)
#      18         if a.func == sp.And:
#      19             if not neg:
# ---> 20                 return demorgan(cnf(a.args[0], depth=depth+1) & demorgan(cnf(eval(str(a.func)+str(a.args[1:])), depth=depth+1), depth=depth+1), depth=depth+1)
#      21             else:
#      22                 return demorgan(cnf(a.args[0], neg=True, depth=depth+1) | demorgan(cnf(eval(str(a.func)+str(a.args[1:])), neg=True, depth=depth+1), depth=depth+1), depth=depth+1)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/logic/boolalg.py in __and__(self, other)
#      61     def __and__(self, other):
#      62         """Overloading for & operator"""
# ---> 63         return And(self, other)
#      64
#      65     __rand__ = __and__
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#     411             # is done so short-circuiting can be done
#     412             # without having to sympify all values
# --> 413             _args = frozenset(cls._new_args_filter(args))
#     414         except ShortCircuit:
#     415             return sympify(cls.zero)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/logic/boolalg.py in _new_args_filter(cls, args)
#     660         newargs = []
#     661         rel = []
# --> 662         args = BooleanFunction.binary_check_and_simplify(*args)
#     663         for x in reversed(args):
#     664             if x.is_Relational:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/logic/boolalg.py in binary_check_and_simplify(self, *args)
#     449         from sympy.core.relational import Relational, Eq, Ne
#     450         args = [as_Boolean(i) for i in args]
# --> 451         bin = set().union(*[i.binary_symbols for i in args])
#     452         rel = set().union(*[i.atoms(Relational) for i in args])
#     453         reps = {}
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/logic/boolalg.py in <listcomp>(.0)
#     449         from sympy.core.relational import Relational, Eq, Ne
#     450         args = [as_Boolean(i) for i in args]
# --> 451         bin = set().union(*[i.binary_symbols for i in args])
#     452         rel = set().union(*[i.atoms(Relational) for i in args])
#     453         reps = {}
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/logic/boolalg.py in binary_symbols(self)
#     163     def binary_symbols(self):
#     164         from sympy.core.relational import Eq, Ne
# --> 165         return set().union(*[i.binary_symbols for i in self.args
#     166                            if i.is_Boolean or i.is_Symbol
#     167                            or isinstance(i, (Eq, Ne))])
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/operations.py in args(self)
#     453     @cacheit
#     454     def args(self):
# --> 455         return tuple(ordered(self._argset))
#     456
#     457     @staticmethod
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     704                     raise ValueError(
#     705                         'not enough keys to break ties: %s' % u)
# --> 706         for v in d[k]:
#     707             yield v
#     708         d.pop(k)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     704                     raise ValueError(
#     705                         'not enough keys to break ties: %s' % u)
# --> 706         for v in d[k]:
#     707             yield v
#     708         d.pop(k)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     685         f = keys.pop(0)
#     686         for a in seq:
# --> 687             d[f(a)].append(a)
#     688     else:
#     689         if not default:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/compatibility.py in default_sort_key(item, order)
#     538
#     539     if isinstance(item, Basic):
# --> 540         return item.sort_key(order=order)
#     541
#     542     if iterable(item, exclude=string_types):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/basic.py in sort_key(self, order)
#     291                 return arg
#     292
# --> 293         args = self._sorted_args
#     294         args = len(args), tuple([inner_key(arg) for arg in args])
#     295         return self.class_key(), args, S.One.sort_key(), S.One
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/basic.py in _sorted_args(self)
#     762         produce the sorted representation.
#     763         """
# --> 764         return self.args
#     765
#     766
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/operations.py in args(self)
#     453     @cacheit
#     454     def args(self):
# --> 455         return tuple(ordered(self._argset))
#     456
#     457     @staticmethod
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     704                     raise ValueError(
#     705                         'not enough keys to break ties: %s' % u)
# --> 706         for v in d[k]:
#     707             yield v
#     708         d.pop(k)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     685         f = keys.pop(0)
#     686         for a in seq:
# --> 687             d[f(a)].append(a)
#     688     else:
#     689         if not default:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/compatibility.py in _nodes(e)
#     589
#     590     if isinstance(e, Basic):
# --> 591         return e.count(Basic)
#     592     elif iterable(e):
#     593         return 1 + sum(_nodes(ei) for ei in e)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/basic.py in count(self, query)
#    1522         """Count the number of matching subexpressions. """
#    1523         query = _make_find_query(query)
# -> 1524         return sum(bool(query(sub)) for sub in preorder_traversal(self))
#    1525
#    1526     def matches(self, expr, repl_dict={}, old=False):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/basic.py in <genexpr>(.0)
#    1522         """Count the number of matching subexpressions. """
#    1523         query = _make_find_query(query)
# -> 1524         return sum(bool(query(sub)) for sub in preorder_traversal(self))
#    1525
#    1526     def matches(self, expr, repl_dict={}, old=False):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sympy/core/basic.py in <lambda>(expr)
#    2018         pass
#    2019     if isinstance(query, type):
# -> 2020         return lambda expr: isinstance(expr, query)
#    2021     elif isinstance(query, Basic):
#    2022         return lambda expr: expr.match(query) is not None
#
# KeyboardInterrupt:
